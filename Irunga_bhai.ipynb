# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
import requests
import os

spark = SparkSession.builder.appName("EIA Electricity Data").getOrCreate()

api_key = 'NPqxwCdaHco8Z5wWQxZCYcREzjU5lEXfvyT7uFka'

url = f"https://api.eia.gov/v2/electricity/electric-power-operational-data/data/?frequency=monthly&data[0]=ash-content&data[1]=consumption-for-eg&data[2]=consumption-for-eg-btu&data[3]=consumption-uto&data[4]=consumption-uto-btu&data[5]=cost&data[6]=cost-per-btu&data[7]=generation&data[8]=heat-content&data[9]=receipts&data[10]=receipts-btu&data[11]=stocks&data[12]=sulfur-content&data[13]=total-consumption&data[14]=total-consumption-btu&facets[location][]=TX&start=2015-01&end=2024-08&sort[0][column]=period&sort[0][direction]=asc&offset=0&length=5000&api_key={api_key}"

output_dir = "data"
os.makedirs(output_dir, exist_ok=True)

response = requests.get(url)

if response.status_code == 200:
    json_file_path = os.path.join(output_dir, "electricity_data.json")
    with open(json_file_path, "w") as json_file:
        json_file.write(response.text)
    print("Electricity data downloaded successfully.")

    df = spark.read.json(json_file_path)
else:
    print(f"Failed to fetch data: {response.status_code} - {response.text}")

# explode the response data to flatten the structure
exploded_df = df.select(
    "ExcelAddInVersion",
    "apiVersion",
    explode(df.response.data).alias("response_data")
)

# selects relevant fields from the exploded DataFrame
final_df = exploded_df.select(
    "ExcelAddInVersion",
    "apiVersion",
    "response_data.*"  # this will bring all fields from the response_data struct
)

print("Final DataFrame:")
final_df.show(truncate=False)
final_df.printSchema()
# Out:
# Electricity data downloaded successfully.
# Final DataFrame:
# +-----------------+----------+-----------+-----------------+------------------+----------------------+----------------------------+------------------------+---------------+-------------------+-------------------------+-----------------------+----+------------+-----------------------+--------------------------+----------------------------------------+----------+-----------+----------------------+------------+----------------------+--------+-------+---------+------------+------------------+-----------------------+---------------------------+--------+----------------+------+-----------------------+--------------+--------------------+-----------------+---------------------+---------------------------+-----------------------+
# |ExcelAddInVersion|apiVersion|ash-content|ash-content-units|consumption-for-eg|consumption-for-eg-btu|consumption-for-eg-btu-units|consumption-for-eg-units|consumption-uto|consumption-uto-btu|consumption-uto-btu-units|consumption-uto-units  |cost|cost-per-btu|cost-per-btu-units     |cost-units                |fuelTypeDescription                     |fueltypeid|generation |generation-units      |heat-content|heat-content-units    |location|period |receipts |receipts-btu|receipts-btu-units|receipts-units         |sectorDescription          |sectorid|stateDescription|stocks|stocks-units           |sulfur-content|sulfur-content-units|total-consumption|total-consumption-btu|total-consumption-btu-units|total-consumption-units|
# +-----------------+----------+-----------+-----------------+------------------+----------------------+----------------------------+------------------------+---------------+-------------------+-------------------------+-----------------------+----+------------+-----------------------+--------------------------+----------------------------------------+----------+-----------+----------------------+------------+----------------------+--------+-------+---------+------------+------------------+-----------------------+---------------------------+--------+----------------+------+-----------------------+--------------+--------------------+-----------------+---------------------+---------------------------+-----------------------+
# |2.1.0            |2.1.7     |5.26       |percent          |2263.836          |37.79133              |million MMBtu               |thousand short tons     |0              |0                  |million MMBtu            |thousand short tons    |NULL|NULL        |dollars per million Btu|dollars per short tons    |subbituminous coal                      |SUB       |3619.90695 |thousand megawatthours|16.6935     |Btu per short tons    |TX      |2015-01|2503.471 |42583.9528  |billion Btu       |thousand short tons    |Independent Power Producers|94      |Texas           |NULL  |thousand short tons    |.33           |percent             |2263.836         |37.79133             |million MMBtu              |thousand short tons    |
# |2.1.0            |2.1.7     |0          |percent          |0                 |0                     |million MMBtu               |thousand short tons     |0              |0                  |million MMBtu            |thousand short tons    |0   |0           |dollars per million Btu|dollars per short tons    |petroleum coke                          |PC        |0          |thousand megawatthours|0           |Btu per short tons    |TX      |2015-01|0        |0           |billion Btu       |thousand short tons    |Independent Power Producers|94      |Texas           |0     |thousand short tons    |0             |percent             |0                |0                    |million MMBtu              |thousand short tons    |
# |2.1.0            |2.1.7     |0          |percent          |0                 |.00196                |million MMBtu               |thousand physical units |0              |0                  |million MMBtu            |thousand physical units|NULL|NULL        |dollars per million Btu|dollars per physical units|other                                   |OTH       |.2106      |thousand megawatthours|0           |Btu per physical units|TX      |2015-01|0        |0           |billion Btu       |thousand physical units|Independent Power Producers|94      |Texas           |NULL  |thousand physical units|0             |percent             |0                |.00196               |million MMBtu              |thousand physical units|
# |2.1.0            |2.1.7     |0          |percent          |0                 |0                     |million MMBtu               |thousand physical units |0              |0                  |million MMBtu            |thousand physical units|NULL|NULL        |dollars per million Btu|dollars per physical units|other renewables                        |ORW       |0          |thousand megawatthours|0           |Btu per physical units|TX      |2015-01|0        |0           |billion Btu       |thousand physical units|Independent Power Producers|94      |Texas           |NULL  |thousand physical units|0             |percent             |0                |0                    |million MMBtu              |thousand physical units|
# |2.1.0            |2.1.7     |0          |percent          |951.503           |.83432                |million MMBtu               |thousand Mcf            |1361.936       |1.13487            |million MMBtu            |thousand Mcf           |NULL|NULL        |dollars per million Btu|dollars per Mcf           |other gases                             |OOG       |135.9343   |thousand megawatthours|.8512       |Btu per Mcf           |TX      |2015-01|0        |0           |billion Btu       |thousand Mcf           |Independent Power Producers|94      |Texas           |NULL  |thousand Mcf           |0             |percent             |2313.439         |1.96918              |million MMBtu              |thousand Mcf           |
# |2.1.0            |2.1.7     |0          |percent          |0                 |0                     |million MMBtu               |thousand physical units |0              |0                  |million MMBtu            |thousand physical units|NULL|NULL        |dollars per million Btu|dollars per physical units|biomass                                 |OBW       |0          |thousand megawatthours|0           |Btu per physical units|TX      |2015-01|0        |0           |billion Btu       |thousand physical units|Independent Power Producers|94      |Texas           |NULL  |thousand physical units|0             |percent             |0                |0                    |million MMBtu              |thousand physical units|
# |2.1.0            |2.1.7     |0          |percent          |0                 |0                     |million MMBtu               |thousand physical units |0              |0                  |million MMBtu            |thousand physical units|NULL|NULL        |dollars per million Btu|dollars per physical units|biomass                                 |OB2       |0          |thousand megawatthours|0           |Btu per physical units|TX      |2015-01|0        |0           |billion Btu       |thousand physical units|Independent Power Producers|94      |Texas           |NULL  |thousand physical units|0             |percent             |0                |0                    |million MMBtu              |thousand physical units|
# |2.1.0            |2.1.7     |9.85       |percent          |0                 |173.60659             |million MMBtu               |thousand physical units |0              |14.24779           |million MMBtu            |thousand physical units|NULL|NULL        |dollars per million Btu|dollars per physical units|fossil fuels                            |FOS       |20642.40998|thousand megawatthours|0           |Btu per physical units|TX      |2015-01|0        |174799.79146|billion Btu       |thousand physical units|Independent Power Producers|94      |Texas           |NULL  |thousand physical units|.59           |percent             |0                |187.85438            |million MMBtu              |thousand physical units|
# |2.1.0            |2.1.7     |NULL       |percent          |NULL              |NULL                  |million MMBtu               |thousand physical units |NULL           |NULL               |million MMBtu            |thousand physical units|0   |NULL        |dollars per million Btu|dollars per physical units|estimated small scale solar photovoltaic|DPV       |0          |thousand megawatthours|NULL        |Btu per physical units|TX      |2015-01|NULL     |NULL        |billion Btu       |thousand physical units|Independent Power Producers|94      |Texas           |NULL  |thousand physical units|NULL          |percent             |NULL             |NULL                 |million MMBtu              |thousand physical units|
# |2.1.0            |2.1.7     |0          |percent          |0                 |39.91608              |million MMBtu               |thousand physical units |0              |0                  |million MMBtu            |thousand physical units|NULL|NULL        |dollars per million Btu|dollars per physical units|nuclear                                 |NUC       |3816.617   |thousand megawatthours|0           |Btu per physical units|TX      |2015-01|0        |0           |billion Btu       |thousand physical units|IPP Non-CHP                |2       |Texas           |NULL  |thousand physical units|0             |percent             |0                |39.91608             |million MMBtu              |thousand physical units|
# |2.1.0            |2.1.7     |0          |percent          |70251.704         |72.14598              |million MMBtu               |thousand Mcf            |0              |0                  |million MMBtu            |thousand Mcf           |NULL|NULL        |dollars per million Btu|dollars per Mcf           |natural gas & other gases               |NGO       |9801.93816 |thousand megawatthours|1.027       |Btu per Mcf           |TX      |2015-01|65533.95 |67328.24139 |billion Btu       |thousand Mcf           |IPP Non-CHP                |2       |Texas           |NULL  |thousand Mcf           |0             |percent             |70251.704        |72.14598             |million MMBtu              |thousand Mcf           |
# |2.1.0            |2.1.7     |0          |percent          |70251.704         |72.14598              |million MMBtu               |thousand Mcf            |0              |0                  |million MMBtu            |thousand Mcf           |NULL|NULL        |dollars per million Btu|dollars per Mcf           |natural gas                             |NG        |9801.93816 |thousand megawatthours|1.027       |Btu per Mcf           |TX      |2015-01|65533.95 |67328.24139 |billion Btu       |thousand Mcf           |IPP Non-CHP                |2       |Texas           |NULL  |thousand Mcf           |0             |percent             |70251.704        |72.14598             |million MMBtu              |thousand Mcf           |
# |2.1.0            |2.1.7     |0          |percent          |0                 |.59478                |million MMBtu               |thousand physical units |0              |0                  |million MMBtu            |thousand physical units|NULL|NULL        |dollars per million Btu|dollars per physical units|municiapl landfill gas                  |MLG       |50.20281   |thousand megawatthours|0           |Btu per physical units|TX      |2015-01|0        |0           |billion Btu       |thousand physical units|IPP Non-CHP                |2       |Texas           |NULL  |thousand physical units|0             |percent             |0                |.59478               |million MMBtu              |thousand physical units|
# +-----------------+----------+-----------+-----------------+------------------+----------------------+----------------------------+------------------------+---------------+-------------------+-------------------------+-----------------------+----+------------+-----------------------+--------------------------+----------------------------------------+----------+-----------+----------------------+------------+----------------------+--------+-------+---------+------------+------------------+-----------------------+---------------------------+--------+----------------+------+-----------------------+--------------+--------------------+-----------------+---------------------+---------------------------+-----------------------+
# only showing top 20 rows
#
# root
#  |-- ExcelAddInVersion: string (nullable = true)
#  |-- apiVersion: string (nullable = true)
#  |-- ash-content: string (nullable = true)
#  |-- ash-content-units: string (nullable = true)
#  |-- consumption-for-eg: string (nullable = true)
#  |-- consumption-for-eg-btu: string (nullable = true)
#  |-- consumption-for-eg-btu-units: string (nullable = true)
#  |-- consumption-for-eg-units: string (nullable = true)
#  |-- consumption-uto: string (nullable = true)
#  |-- consumption-uto-btu: string (nullable = true)
#  |-- consumption-uto-btu-units: string (nullable = true)
#  |-- consumption-uto-units: string (nullable = true)
#  |-- cost: string (nullable = true)
#  |-- cost-per-btu: string (nullable = true)
#  |-- cost-per-btu-units: string (nullable = true)
#  |-- cost-units: string (nullable = true)
#  |-- fuelTypeDescription: string (nullable = true)
#  |-- fueltypeid: string (nullable = true)
#  |-- generation: string (nullable = true)
#  |-- generation-units: string (nullable = true)
#  |-- heat-content: string (nullable = true)
#  |-- heat-content-units: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- period: string (nullable = true)
#  |-- receipts: string (nullable = true)
#  |-- receipts-btu: string (nullable = true)
#  |-- receipts-btu-units: string (nullable = true)
#  |-- receipts-units: string (nullable = true)
#  |-- sectorDescription: string (nullable = true)
#  |-- sectorid: string (nullable = true)
#  |-- stateDescription: string (nullable = true)
#  |-- stocks: string (nullable = true)
#  |-- stocks-units: string (nullable = true)
#  |-- sulfur-content: string (nullable = true)
#  |-- sulfur-content-units: string (nullable = true)
#  |-- total-consumption: string (nullable = true)
#  |-- total-consumption-btu: string (nullable = true)
#  |-- total-consumption-btu-units: string (nullable = true)
#  |-- total-consumption-units: string (nullable = true)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import DoubleType

# Assuming final_df is already created and contains your data

# Drop rows with any null values
final_df = final_df.dropna()

# List of columns that need to be converted to numeric types
numeric_columns = [
    'ash-content',
    'consumption-for-eg',
    'consumption-for-eg-btu',
    'consumption-uto',
    'consumption-uto-btu',
    'cost',
    'cost-per-btu',
    'generation',
    'heat-content',
    'receipts',
    'stocks',
    'sulfur-content',
    'total-consumption',
    'total-consumption-btu'
]

for column in numeric_columns:
    final_df = final_df.withColumn(column, final_df[column].cast(DoubleType()))
final_df.show(truncate=False)
final_df.printSchema()
# Out:
# +-----------------+----------+-----------+-----------------+------------------+----------------------+----------------------------+------------------------+---------------+-------------------+-------------------------+---------------------+------+------------+-----------------------+----------------------+--------------------------+----------+----------+----------------------+------------+------------------+--------+-------+--------+------------+------------------+-------------------+---------------------------+--------+----------------+--------+-------------------+--------------+--------------------+-----------------+---------------------+---------------------------+-----------------------+
# |ExcelAddInVersion|apiVersion|ash-content|ash-content-units|consumption-for-eg|consumption-for-eg-btu|consumption-for-eg-btu-units|consumption-for-eg-units|consumption-uto|consumption-uto-btu|consumption-uto-btu-units|consumption-uto-units|cost  |cost-per-btu|cost-per-btu-units     |cost-units            |fuelTypeDescription       |fueltypeid|generation|generation-units      |heat-content|heat-content-units|location|period |receipts|receipts-btu|receipts-btu-units|receipts-units     |sectorDescription          |sectorid|stateDescription|stocks  |stocks-units       |sulfur-content|sulfur-content-units|total-consumption|total-consumption-btu|total-consumption-btu-units|total-consumption-units|
# +-----------------+----------+-----------+-----------------+------------------+----------------------+----------------------------+------------------------+---------------+-------------------+-------------------------+---------------------+------+------------+-----------------------+----------------------+--------------------------+----------+----------+----------------------+------------+------------------+--------+-------+--------+------------+------------------+-------------------+---------------------------+--------+----------------+--------+-------------------+--------------+--------------------+-----------------+---------------------+---------------------------+-----------------------+
# |2.1.0            |2.1.7     |0.0        |percent          |0.0               |0.0                   |million MMBtu               |thousand short tons     |0.0            |0.0                |million MMBtu            |thousand short tons  |0.0   |0.0         |dollars per million Btu|dollars per short tons|petroleum coke            |PC        |0.0       |thousand megawatthours|0.0         |Btu per short tons|TX      |2015-01|0.0     |0           |billion Btu       |thousand short tons|Independent Power Producers|94      |Texas           |0.0     |thousand short tons|0.0           |percent             |0.0              |0.0                  |million MMBtu              |thousand short tons    |
# |2.1.0            |2.1.7     |0.0        |percent          |6.729             |0.03946               |million MMBtu               |thousand barrels        |0.001          |1.0E-5             |million MMBtu            |thousand barrels     |80.38 |13.6327     |dollars per million Btu|dollars per barrels   |petroleum liquids         |PEL       |3.50959   |thousand megawatthours|5.8647      |Btu per barrels   |TX      |2015-01|3.528   |20.80032    |billion Btu       |thousand barrels   |Electric Utility           |1       |Texas           |693.099 |thousand barrels   |0.0           |percent             |6.73             |0.03947              |million MMBtu              |thousand barrels       |
# |2.1.0            |2.1.7     |0.0        |percent          |0.0               |0.0                   |million MMBtu               |thousand short tons     |0.0            |0.0                |million MMBtu            |thousand short tons  |0.0   |0.0         |dollars per million Btu|dollars per short tons|petroleum coke            |PC        |0.0       |thousand megawatthours|0.0         |Btu per short tons|TX      |2015-01|0.0     |0           |billion Btu       |thousand short tons|Electric Power             |98      |Texas           |0.0     |thousand short tons|0.0           |percent             |0.0              |0.0                  |million MMBtu              |thousand short tons    |
# |2.1.0            |2.1.7     |6.91       |percent          |2795.354          |45.00849              |million MMBtu               |thousand short tons     |0.0            |0.0                |million MMBtu            |thousand short tons  |36.36 |2.2243      |dollars per million Btu|dollars per short tons|coal, excluding waste coal|COL       |4213.48497|thousand megawatthours|16.1012     |Btu per short tons|TX      |2015-01|3504.042|57274.29718 |billion Btu       |thousand short tons|Electric Utility           |1       |Texas           |5874.829|thousand short tons|0.37          |percent             |2795.354         |45.00849             |million MMBtu              |thousand short tons    |
# |2.1.0            |2.1.7     |0.0        |percent          |0.183             |0.00106               |million MMBtu               |thousand barrels        |1.259          |0.0073             |million MMBtu            |thousand barrels     |0.0   |0.0         |dollars per million Btu|dollars per barrels   |petroleum liquids         |PEL       |0.13857   |thousand megawatthours|5.8005      |Btu per barrels   |TX      |2015-01|0.0     |0           |billion Btu       |thousand barrels   |All Industrial             |97      |Texas           |0.141   |thousand barrels   |0.0           |percent             |1.442            |0.00837              |million MMBtu              |thousand barrels       |
# |2.1.0            |2.1.7     |0.0        |percent          |0.068             |4.0E-4                |million MMBtu               |thousand barrels        |0.05           |2.9E-4             |million MMBtu            |thousand barrels     |0.0   |0.0         |dollars per million Btu|dollars per barrels   |petroleum liquids         |PEL       |0.03685   |thousand megawatthours|5.8019      |Btu per barrels   |TX      |2015-01|0.0     |0           |billion Btu       |thousand barrels   |All Commercial             |96      |Texas           |22.699  |thousand barrels   |0.0           |percent             |0.118            |6.9E-4               |million MMBtu              |thousand barrels       |
# |2.1.0            |2.1.7     |0.0        |percent          |0.0               |0.0                   |million MMBtu               |thousand short tons     |0.0            |0.0                |million MMBtu            |thousand short tons  |0.0   |0.0         |dollars per million Btu|dollars per short tons|petroleum coke            |PC        |0.0       |thousand megawatthours|0.0         |Btu per short tons|TX      |2015-02|0.0     |0           |billion Btu       |thousand short tons|Independent Power Producers|94      |Texas           |0.0     |thousand short tons|0.0           |percent             |0.0              |0.0                  |million MMBtu              |thousand short tons    |
# |2.1.0            |2.1.7     |0.0        |percent          |5.09              |0.02986               |million MMBtu               |thousand barrels        |0.001          |1.0E-5             |million MMBtu            |thousand barrels     |84.57 |14.5455     |dollars per million Btu|dollars per barrels   |petroleum liquids         |PEL       |2.58894   |thousand megawatthours|5.8676      |Btu per barrels   |TX      |2015-02|3.568   |20.74566    |billion Btu       |thousand barrels   |Electric Utility           |1       |Texas           |694.036 |thousand barrels   |0.0           |percent             |5.091            |0.02987              |million MMBtu              |thousand barrels       |
# |2.1.0            |2.1.7     |0.0        |percent          |0.0               |0.0                   |million MMBtu               |thousand short tons     |0.0            |0.0                |million MMBtu            |thousand short tons  |0.0   |0.0         |dollars per million Btu|dollars per short tons|petroleum coke            |PC        |0.0       |thousand megawatthours|0.0         |Btu per short tons|TX      |2015-02|0.0     |0           |billion Btu       |thousand short tons|Electric Power             |98      |Texas           |0.0     |thousand short tons|0.0           |percent             |0.0              |0.0                  |million MMBtu              |thousand short tons    |
# |2.1.0            |2.1.7     |6.6        |percent          |2168.295          |34.56445              |million MMBtu               |thousand short tons     |0.0            |0.0                |million MMBtu            |thousand short tons  |35.62 |2.167       |dollars per million Btu|dollars per short tons|coal, excluding waste coal|COL       |3198.5753 |thousand megawatthours|15.9408     |Btu per short tons|TX      |2015-02|2754.982|45278.78157 |billion Btu       |thousand short tons|Electric Utility           |1       |Texas           |6587.689|thousand short tons|0.38          |percent             |2168.295         |34.56445             |million MMBtu              |thousand short tons    |
# |2.1.0            |2.1.7     |0.0        |percent          |0.07              |4.1E-4                |million MMBtu               |thousand barrels        |0.053          |3.0E-4             |million MMBtu            |thousand barrels     |0.0   |0.0         |dollars per million Btu|dollars per barrels   |petroleum liquids         |PEL       |0.03788   |thousand megawatthours|5.8016      |Btu per barrels   |TX      |2015-02|0.0     |0           |billion Btu       |thousand barrels   |All Commercial             |96      |Texas           |23.212  |thousand barrels   |0.0           |percent             |0.123            |7.1E-4               |million MMBtu              |thousand barrels       |
# |2.1.0            |2.1.7     |0.0        |percent          |0.108             |6.3E-4                |million MMBtu               |thousand barrels        |0.081          |4.7E-4             |million MMBtu            |thousand barrels     |0.0   |0.0         |dollars per million Btu|dollars per barrels   |petroleum liquids         |PEL       |0.05799   |thousand megawatthours|5.8016      |Btu per barrels   |TX      |2015-04|0.0     |0           |billion Btu       |thousand barrels   |All Commercial             |96      |Texas           |24.069  |thousand barrels   |0.0           |percent             |0.189            |0.0011               |million MMBtu              |thousand barrels       |
# |2.1.0            |2.1.7     |0.0        |percent          |0.0               |0.0                   |million MMBtu               |thousand short tons     |0.0            |0.0                |million MMBtu            |thousand short tons  |0.0   |0.0         |dollars per million Btu|dollars per short tons|petroleum coke            |PC        |0.0       |thousand megawatthours|0.0         |Btu per short tons|TX      |2015-04|0.0     |0           |billion Btu       |thousand short tons|Electric Power             |98      |Texas           |0.0     |thousand short tons|0.0           |percent             |0.0              |0.0                  |million MMBtu              |thousand short tons    |
# +-----------------+----------+-----------+-----------------+------------------+----------------------+----------------------------+------------------------+---------------+-------------------+-------------------------+---------------------+------+------------+-----------------------+----------------------+--------------------------+----------+----------+----------------------+------------+------------------+--------+-------+--------+------------+------------------+-------------------+---------------------------+--------+----------------+--------+-------------------+--------------+--------------------+-----------------+---------------------+---------------------------+-----------------------+
# only showing top 20 rows
#
# root
#  |-- ExcelAddInVersion: string (nullable = true)
#  |-- apiVersion: string (nullable = true)
#  |-- ash-content: double (nullable = true)
#  |-- ash-content-units: string (nullable = true)
#  |-- consumption-for-eg: double (nullable = true)
#  |-- consumption-for-eg-btu: double (nullable = true)
#  |-- consumption-for-eg-btu-units: string (nullable = true)
#  |-- consumption-for-eg-units: string (nullable = true)
#  |-- consumption-uto: double (nullable = true)
#  |-- consumption-uto-btu: double (nullable = true)
#  |-- consumption-uto-btu-units: string (nullable = true)
#  |-- consumption-uto-units: string (nullable = true)
#  |-- cost: double (nullable = true)
#  |-- cost-per-btu: double (nullable = true)
#  |-- cost-per-btu-units: string (nullable = true)
#  |-- cost-units: string (nullable = true)
#  |-- fuelTypeDescription: string (nullable = true)
#  |-- fueltypeid: string (nullable = true)
#  |-- generation: double (nullable = true)
#  |-- generation-units: string (nullable = true)
#  |-- heat-content: double (nullable = true)
#  |-- heat-content-units: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- period: string (nullable = true)
#  |-- receipts: double (nullable = true)
#  |-- receipts-btu: string (nullable = true)
#  |-- receipts-btu-units: string (nullable = true)
#  |-- receipts-units: string (nullable = true)
#  |-- sectorDescription: string (nullable = true)
#  |-- sectorid: string (nullable = true)
#  |-- stateDescription: string (nullable = true)
#  |-- stocks: double (nullable = true)
#  |-- stocks-units: string (nullable = true)
#  |-- sulfur-content: double (nullable = true)
#  |-- sulfur-content-units: string (nullable = true)
#  |-- total-consumption: double (nullable = true)
#  |-- total-consumption-btu: double (nullable = true)
#  |-- total-consumption-btu-units: string (nullable = true)
#  |-- total-consumption-units: string (nullable = true)
